# %%
import os
#os.chdir('/home/apiso/repos/core_accretion/python')
os.chdir('/Users/ana-mariapiso/core_accretion/python')

import numpy
from utils.constants import Me, Re, gammafn, Rfn, Cvfn, Pdisk, Tdisk, kdust, \
     params, mufn
from utils.userpath import userpath
from utils.parameters import FSigma, FT, mstar
import matplotlib.pyplot as plt
from RadSGPoly import plot_helper as ph
from RadSGPoly.profiles_poly import atmload
import matplotlib.cm as cm

reload(ph)
# Out:
# <module 'RadSGPoly.plot_helper' from 'RadSGPoly/plot_helper.pyc'>

# %%
a = 10.0
delad27 = 2./7
delad25 = 2./5
Y00 = 0.0
Y03 = 0.3

prms00 = params(Me, Re, a, delad27, Y00, gamma = gammafn(delad27), R = Rfn(Y00), \
              Cv = Cvfn(Y00, delad27), Pd = Pdisk(a, mstar, FSigma, FT), \
              Td = Tdisk(a, FT), kappa = kdust)

prms03 = params(Me, Re, a, delad27, Y03, gamma = gammafn(delad27), R = Rfn(Y03), \
              Cv = Cvfn(Y03, delad27), Pd = Pdisk(a, mstar, FSigma, FT), \
              Td = Tdisk(a, FT), kappa = kdust)

prms03m = params(Me, Re, a, delad25, Y03, gamma = gammafn(delad25), R = Rfn(Y03), \
              Cv = Cvfn(Y03, delad25), Pd = Pdisk(a, mstar, FSigma, FT), \
              Td = Tdisk(a, FT), kappa = kdust)

# %%
atm001 = atmload('Mc5.0.npz', prms = prms00)
atm002 = atmload('Mc6.0.npz', prms = prms00)
atm003 = atmload('Mc7.0.npz', prms = prms00)
atm004 = atmload('Mc8.0.npz', prms = prms00)
atm005 = atmload('Mc9.0.npz', prms = prms00)
atm006 = atmload('Mc10.0.npz', prms = prms00)
atm007 = atmload('Mc11.0.npz', prms = prms00)
atm008 = atmload('Mc12.0.npz', prms = prms00)
atm009 = atmload('Mc13.0.npz', prms = prms00)
atm0010 = atmload('Mc14.0.npz', prms = prms00)

# %%
atm031 = atmload('Mc1.0.npz', prms = prms03)
atm032 = atmload('Mc2.0.npz', prms = prms03)
atm033 = atmload('Mc3.0.npz', prms = prms03)
atm034 = atmload('Mc4.0.npz', prms = prms03)
atm035 = atmload('Mc5.0.npz', prms = prms03)
atm036 = atmload('Mc6.0.npz', prms = prms03)
atm037 = atmload('Mc7.0.npz', prms = prms03)
atm038 = atmload('Mc8.0.npz', prms = prms03)
atm039 = atmload('Mc9.0.npz', prms = prms03)
atm0310 = atmload('Mc10.0.npz', prms = prms03)

# %%
atm031m = atmload('Mc1.0.npz', prms = prms03m)
atm032m = atmload('Mc2.0.npz', prms = prms03m)
atm033m = atmload('Mc3.0.npz', prms = prms03m)
atm034m = atmload('Mc4.0.npz', prms = prms03m)
atm035m = atmload('Mc5.0.npz', prms = prms03m)
atm036m = atmload('Mc6.0.npz', prms = prms03m)
atm037m = atmload('Mc7.0.npz', prms = prms03m)
atm038m = atmload('Mc8.0.npz', prms = prms03m)
atm039m = atmload('Mc9.0.npz', prms = prms03m)
atm0310m = atmload('Mc10.0.npz', prms = prms03m)

# %%
model00 = [atm001[0], atm002[0], atm003[0], atm004[0], atm005[0], atm006[0], atm007[0], atm008[0], atm009[0], atm0010[0]]
param00 = [atm001[1], atm002[1], atm003[1], atm004[1], atm005[1], atm006[1], atm007[1], atm008[1], atm009[1], atm0010[1]]

model03 = [atm031[0], atm032[0], atm033[0], atm034[0], atm035[0], atm036[0], atm037[0], atm038[0], atm039[0], atm0310[0]]
param03 = [atm031[1], atm032[1], atm033[1], atm034[1], atm035[1], atm036[1], atm037[1], atm038[1], atm039[1], atm0310[1]]

model03m = [atm031m[0], atm032m[0], atm033m[0], atm034m[0], atm035m[0], atm036m[0], atm037m[0], atm038m[0], atm039m[0], atm0310m[0]]
param03m = [atm031m[1], atm032m[1], atm033m[1], atm034m[1], atm035m[1], atm036m[1], atm037m[1], atm038m[1], atm039m[1], atm0310m[1]]

Mc00 = numpy.linspace(5, 14, 10)
Mc03 = numpy.linspace(1, 10, 10)
Mc03m = numpy.linspace(1, 10, 10)

# %%
Mct_a10_00 = ph.t_vs_Mc_fixed_a(2. / 7, 0.0, a, returnt = 1)
Mct_a10_03 = ph.t_vs_Mc_fixed_a(2. / 7, 0.3, a, returnt = 1)
Mct_a10_03m = ph.t_vs_Mc_fixed_a(2. / 5, 0.3, a, returnt = 1)

# %%
Mc00 = Mct_a10_00[0]
ttot00 = Mct_a10_00[1]
Mcrittot00 = Mct_a10_00[2]
dt00 = Mct_a10_00[3]
tcum00 = Mct_a10_00[4]

Mc03 = Mct_a10_03[0]
ttot03 = Mct_a10_03[1]
Mcrittot03 = Mct_a10_03[2]
dt03 = Mct_a10_03[3]
tcum03 = Mct_a10_03[4]

Mc03m = Mct_a10_03m[0]
ttot03m = Mct_a10_03m[1]
Mcrittot03m = Mct_a10_03m[2]
dt03m = Mct_a10_03m[3]
tcum03m = Mct_a10_03m[4]

# %%
savefig = 1
filename = 'coolingtime_vs_Mc_10au.pdf'

plt.figure(figsize = (4.5, 4.5*2./3))

plt.semilogy(Mc03, ttot03 / 10**6, '-o', label = r'$\nabla_{\mathrm{ad}}=2/7$, $\mu=$' + str(mufn(Y03))[:4])
plt.semilogy(Mc00, ttot00 / 10**6, '-sr', label = r'$\nabla_{\mathrm{ad}}=2/7$, $\mu=$' + str(mufn(Y00)))
#plt.semilogy(Mc03m, ttot03m / 10**6, '-g^', label = r'$\nabla_{\mathrm{ad}}=2/5$,  $\mu=$' + str(mufn(Y03))[:4])
plt.axhline(y = 3, linestyle = '--', color = 'black', label = 't = 3 Myrs')
plt.xlabel(r'$M_c (M_{\oplus})$ ')
plt.ylabel(r'$t_{\mathrm{cool}}$(Myrs)')
plt.xlim(4.5, 14.5)
plt.legend(prop = {'size':10.7})
plt.title(r'a=' + str(int(a)) + ' AU')

plt.tight_layout()
if savefig != 0:
    plt.savefig(userpath + '/figs/ModelAtmospheres/RadSelfGravPoly/PaperFigs/' + filename)
plt.show()

# %%
Mct_a10_03 = ph.t_vs_Mc_fixed_a(2. / 7, 0.3, a, returnt = 1)

# %%
rnb = numpy.linspace(0, 256, 10)
mtot = 0
savefig = 0
filename = 'cumul_coolingtime_vs_Matm_10au_mu2.pdf'

if mtot == 0:

    for i in range(10):
        plt.semilogy(param00[i].MB[1:] - Mc00[i], tcum00[i], c = cm.rainbow(numpy.int(rnb[i])), \
                     label = r' %s $M_{\oplus}$' % str(Mc00[i]))
        plt.semilogy(Mcrittot00[i] - Mc00[i], ttot00[i], 'o', c = cm.rainbow(numpy.int(rnb[i])))
    plt.xlabel(r'$M_{\mathrm{atm}}(M_{\oplus})$')
    plt.xlim(0,20)
    
else:
    for i in range(10):
        plt.semilogy(param00[i].MB[1:], tcum00[i], c = cm.rainbow(numpy.int(rnb[i])), \
                     label = r' %s $M_{\oplus}$' % str(Mc00[i]))
        plt.semilogy(Mcrittot00[i], ttot00[i], 'o', c = cm.rainbow(numpy.int(rnb[i])))
    plt.xlabel(r'$M(M_{\oplus})$')
        
plt.legend(loc = 4, prop = {'size':10})
plt.ylabel(r'$t$ (yrs)')
plt.title(r'$\nabla_{\mathrm{ad}}=2/7$, $\mu=$' + str(mufn(Y00)))
if savefig != 0:
    plt.savefig(userpath + '/figs/ModelAtmospheres/RadSelfGravPoly/' + filename)

# %%
rnb = numpy.linspace(0, 256, 10)
mtot = 0
savefig = 1
filename = 'cumul_coolingtime_vs_Matm_10au_mu235.pdf'


plt.figure(figsize = (4.5, 4.5*2./3))
if mtot == 0:

    for i in range(10):
        plt.semilogy(param03[i].MB[1:] - Mc03[i], tcum03[i], c = cm.rainbow(numpy.int(rnb[i])), \
                     label = r' %s $M_{\oplus}$' % str(Mc03[i]))
        plt.semilogy(Mcrittot03[i] - Mc03[i], ttot03[i], 'o', c = cm.rainbow(numpy.int(rnb[i])))
        plt.text((Mcrittot03[i] - Mc03[i])*1.03, ttot03[i]*1.7, '%s' % str(int(Mc03[i])))
    plt.xlabel(r'$M_{\mathrm{atm}}[M_{\oplus}]$')
    plt.xlim(0,11)
    plt.ylim(10, 5*10**9)
    
else:
    for i in range(10):
        plt.semilogy(param03[i].MB[1:], tcum03[i], c = cm.rainbow(numpy.int(rnb[i])), \
                     label = r' %s $M_{\oplus}$' % str(Mc03[i]))
        plt.semilogy(Mcrittot03[i], ttot03[i], 'o', c = cm.rainbow(numpy.int(rnb[i])))
    plt.xlabel(r'$M(M_{\oplus})$')
        
#plt.legend(loc = 4, prop = {'size':5})
plt.ylabel(r'$t$ [yrs]')
plt.title(r'$a=10 \mathrm{AU}$, $\nabla_{\mathrm{ad}}=2/7$, $\mu=$' + str(mufn(Y03))[:4])
if savefig != 0:
    plt.savefig(userpath + '/figs/ModelAtmospheres/RadSelfGravPoly/PaperFigs/' + filename)

# %%
rnb = numpy.linspace(0, 256, 10)
mtot = 0
savefig = 0
filename = 'cumul_coolingtime_vs_Matm_10au_mu235_delad25.pdf'

if mtot == 0:

    for i in range(10):
        plt.semilogy(param03m[i].MB[1:] - Mc03m[i], tcum03m[i], c = cm.rainbow(numpy.int(rnb[i])), \
                     label = r' %s $M_{\oplus}$' % str(Mc03m[i]))
        plt.semilogy(Mcrittot03m[i] - Mc03m[i], ttot03m[i], 'o', c = cm.rainbow(numpy.int(rnb[i])))
    plt.xlabel(r'$M_{\mathrm{atm}}(M_{\oplus})$')
    plt.xlim(0,15)
    
else:
    for i in range(10):
        plt.semilogy(param03m[i].MB[1:], tcum03m[i], c = cm.rainbow(numpy.int(rnb[i])), \
                     label = r' %s $M_{\oplus}$' % str(Mc03m[i]))
        plt.semilogy(Mcrittot03m[i], ttot03m[i], 'o', c = cm.rainbow(numpy.int(rnb[i])))
    plt.xlabel(r'$M(M_{\oplus})$')
        
plt.legend(loc = 4, prop = {'size':10})
plt.ylabel(r'$t$ (yrs)')
plt.title(r'$\nabla_{\mathrm{ad}}=2/5$, $\mu=$' + str(mufn(Y03))[:4])
if savefig != 0:
    plt.savefig(userpath + '/figs/ModelAtmospheres/RadSelfGravPoly/' + filename)

# %%
rnb = numpy.linspace(0, 256, 10)
mtot = 0
savefig = 0
filename = 'coolingtime_vs_Matm_10au_mu235.pdf'


#plt.figure(figsize = (10.75/1.7, 5.33/1.7))
if mtot == 0:

    for i in range(10):
        plt.loglog(param03[i].MB[1:] - Mc03[i], dt03[i], c = cm.rainbow(numpy.int(rnb[i])), \
                     label = r' %s $M_{\oplus}$' % str(Mc03[i]))
        #plt.semilogy(Mcrittot03[i] - Mc03[i], ttot03[i], 'o', c = cm.rainbow(numpy.int(rnb[i])))
    plt.xlabel(r'$M_{\mathrm{atm}}(M_{\oplus})$')
    #plt.xlim(0,14)
    
else:
    for i in range(10):
        plt.loglog(param03[i].MB[1:], dt03[i], c = cm.rainbow(numpy.int(rnb[i])), \
                     label = r' %s $M_{\oplus}$' % str(Mc03[i]))
        #plt.semilogy(Mcrittot03[i], ttot03[i], 'o', c = cm.rainbow(numpy.int(rnb[i])))
    plt.xlabel(r'$M(M_{\oplus})$')
        
plt.legend(loc = 4, prop = {'size':5})
plt.ylabel(r'$\Delta t$ (yrs)')
plt.title(r'$a=10 \mathrm{AU}$, $\nabla_{\mathrm{ad}}=2/7$, $\mu=$' + str(mufn(Y03))[:4])
if savefig != 0:
    plt.savefig(userpath + '/figs/ModelAtmospheres/RadSelfGravPoly/' + filename)

# %%
au = numpy.linspace(10, 100, 10)

crit00 = ph.Mc_vs_a_fixed_t(2. / 7, 0.0, 3 * 10**6)
crit03 = ph.Mc_vs_a_fixed_t(2. / 7, 0.3, 3 * 10**6)
#crit03m = ph.Mc_vs_a_fixed_t(2. / 5, 0.3, 3 * 10**6)
# Out:
# IOError: [Errno 24] Too many open files: '/Users/ana-mariapiso/core_accretion/dat_ana/MODELS/RadSGPoly/delad0.28/Y0.3/70.0AU/Mc2.0.npz'
# Traceback (most recent call last):
#   File "/Library/Frameworks/EPD64.framework/Versions/7.2/lib/python2.7/site-packages/ipython-0.13.1-py2.7.egg/IPython/core/ultratb.py", line 756, in structured_traceback
#   File "/Library/Frameworks/EPD64.framework/Versions/7.2/lib/python2.7/site-packages/ipython-0.13.1-py2.7.egg/IPython/core/ultratb.py", line 242, in _fixed_getinnerframes
#   File "/Library/Frameworks/EPD64.framework/Versions/7.2/lib/python2.7/inspect.py", line 1041, in getinnerframes
#   File "/Library/Frameworks/EPD64.framework/Versions/7.2/lib/python2.7/inspect.py", line 1005, in getframeinfo
#   File "/Library/Frameworks/EPD64.framework/Versions/7.2/lib/python2.7/inspect.py", line 530, in findsource
#   File "/Library/Frameworks/EPD64.framework/Versions/7.2/lib/python2.7/inspect.py", line 499, in getmodule
# ...

# %%
au00 = crit00[0]
au03 = crit03[0]
au03m = crit03m[0]

Mcrit00 = crit00[1]
Mcrit03 = crit03[1]
Mcrit03m = crit03m[1]
# Out:
# The history saving thread hit an unexpected error (OperationalError('unable to open database file',)).History will not be written to the database.
# Traceback (most recent call last):
# NameError: name 'crit03' is not defined
#   File "/Library/Frameworks/EPD64.framework/Versions/7.2/lib/python2.7/site-packages/ipython-0.13.1-py2.7.egg/IPython/core/ultratb.py", line 756, in structured_traceback
#   File "/Library/Frameworks/EPD64.framework/Versions/7.2/lib/python2.7/site-packages/ipython-0.13.1-py2.7.egg/IPython/core/ultratb.py", line 242, in _fixed_getinnerframes
#   File "/Library/Frameworks/EPD64.framework/Versions/7.2/lib/python2.7/inspect.py", line 1041, in getinnerframes
#   File "/Library/Frameworks/EPD64.framework/Versions/7.2/lib/python2.7/inspect.py", line 1005, in getframeinfo
#   File "/Library/Frameworks/EPD64.framework/Versions/7.2/lib/python2.7/inspect.py", line 530, in findsource
# ...

# %%
fig = plt.figure(figsize = (14.17/2, 6.04/2))
ax = fig.add_subplot(1,1,1)

savefig = 0

ax.semilogx(au, Mcrit00, '-o', label = r'$\nabla_{\mathrm{ad}}=2/7$, $\mu=$' + str(mufn(Y00))[:4])
ax.semilogx(au, Mcrit03, '-rs', label = r'$\nabla_{\mathrm{ad}}=2/7$, $\mu=$' + str(mufn(Y03))[:4])
ax.semilogx(au, Mcrit03m, '-g^', label = r'$\nabla_{\mathrm{ad}}=2/5$, $\mu=$' + str(mufn(Y03))[:4])
ax.set_xlabel('a [AU]')
ax.set_ylabel(r'$M_c [M_{\oplus}]$ ')
ax.set_xticks((10, 20, 40, 60, 80, 100))
ax.set_xticklabels(("10", "20", "40", "60", "80", "100"))
ax.set_xlim(9, 105)
ax.set_ylim(3, 12)
ax.legend()
ax.set_title(r'Critical core mass vs. distance for disk lifetime of 3 Myrs')
if savefig == 1:
    plt.savefig(userpath + \
                '/figs/ModelAtmospheres/RadSelfGravPoly/Mcrit_vs_a_3Myrs.pdf')
# Out:
# NameError: name 'Mcrit03' is not defined
# ERROR: Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# Unfortunately, your original traceback can not be constructed.
# ERROR: Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Library/Frameworks/EPD64.framework/Versions/7.2/lib/python2.7/site-packages/ipython-0.13.1-py2.7.egg/IPython/core/ultratb.py", line 756, in structured_traceback
#   File "/Library/Frameworks/EPD64.framework/Versions/7.2/lib/python2.7/site-packages/ipython-0.13.1-py2.7.egg/IPython/core/ultratb.py", line 242, in _fixed_getinnerframes
#   File "/Library/Frameworks/EPD64.framework/Versions/7.2/lib/python2.7/inspect.py", line 1041, in getinnerframes
#   File "/Library/Frameworks/EPD64.framework/Versions/7.2/lib/python2.7/inspect.py", line 1005, in getframeinfo
# ...
