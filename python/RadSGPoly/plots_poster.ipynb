# %%
import os
#os.chdir('/home/apiso/repos/core_accretion/python')
os.chdir('/Users/ana-mariapiso/core_accretion/python')

# %%
import numpy
from utils.constants import Me, Re, gammafn, Rfn, Cvfn, Pdisk, Tdisk, kdust, \
     params, mufn
from Analytical.analytic_comp import analytic_sols as ansols
from utils.userpath import userpath
from utils.parameters import FSigma, FT, mstar
import matplotlib.pyplot as plt
from RadSGPoly import plot_helper as ph
from RadSGPoly.profiles_poly import atmload
from RadSGPoly.cooling_poly import critical
import matplotlib.cm as cm

# %%
a = 60.0
a10 = 10.0
a30 = 30.0

Mc = 5.0
delad27 = 2./7
Y03 = 0.3

prms = params(Me, Re, a, delad27, Y03, gamma = gammafn(delad27), R = Rfn(Y03), \
              Cv = Cvfn(Y03, delad27), Pd = Pdisk(a, mstar, FSigma, FT), \
              Td = Tdisk(a, FT), kappa = kdust)

prms10 = params(Me, Re, a10, delad27, Y03, gamma = gammafn(delad27), R = Rfn(Y03), \
              Cv = Cvfn(Y03, delad27), Pd = Pdisk(a10, mstar, FSigma, FT), \
              Td = Tdisk(a10, FT), kappa = kdust)

prms30 = params(Me, Re, a30, delad27, Y03, gamma = gammafn(delad27), R = Rfn(Y03), \
              Cv = Cvfn(Y03, delad27), Pd = Pdisk(a30, mstar, FSigma, FT), \
              Td = Tdisk(a30, FT), kappa = kdust)

# %%
atm = atmload('Mc5.0.npz', prms = prms)
atm10 = atmload('Mc5.0.npz', prms = prms10)
atm30 = atmload('Mc5.0.npz', prms = prms30)

# %%
model, param, prof = atm[0], atm[1], atm[2]
model10, param10, prof10 = atm10[0], atm10[1], atm10[2]
model30, param30, prof30 = atm30[0], atm30[1], atm30[2]

# %%
crit = critical(param, prof, model)
crit10 = critical(param10, prof10, model10)
crit30 = critical(param30, prof30, model30)

# %%
paramcrit = crit[0]
profcrit = crit[1]
dtcrit = crit[2]

paramcrit10 = crit10[0]
profcrit10 = crit10[1]
dtcrit10 = crit10[2]

paramcrit30 = crit30[0]
profcrit30 = crit30[1]
dtcrit30 = crit30[2]

# %%
i1 = 2
i2 = 50

r1, r2, r3 = profcrit.r[i1] / Re, profcrit.r[i2] / Re, profcrit.r[-1] / Re
P1, P2, P3 = profcrit.P[i1], profcrit.P[i2], profcrit.P[-1]
T1, T2, T3 = profcrit.t[i1], profcrit.t[i2], profcrit.t[-1]
m1, m2, m3 = profcrit.m[i1] / Me, profcrit.m[i2] / Me, profcrit.m[-1] / Me

MB1 = paramcrit.MB[i1]
MB2 = paramcrit.MB[i2]
MB3 = paramcrit.MB[-1]

RB1 = paramcrit.RB[i1]
RB2 = paramcrit.RB[i2]
RB3 = paramcrit.RB[-1]

rcb1 = paramcrit.rcb[i1]
rcb2 = paramcrit.rcb[i2]
rcb3 = paramcrit.rcb[-1]

PB1, TB1, Pcb1, Tcb1, Mcb1 = paramcrit.PB[i1], paramcrit.TB[i1], paramcrit.Pcb[i1], paramcrit.Tcb[i1], paramcrit.Mcb[i1]
PB2, TB2, Pcb2, Tcb2, Mcb2 = paramcrit.PB[i2], paramcrit.TB[i2], paramcrit.Pcb[i2], paramcrit.Tcb[i2], paramcrit.Mcb[i2]
PB3, TB3, Pcb3, Tcb3, Mcb3 = paramcrit.PB[-1], paramcrit.TB[-1], paramcrit.Pcb[-1], paramcrit.Tcb[-1], paramcrit.Mcb[-1]

M = paramcrit.MB
dM = M[1:]-M[:-1]

M10 = paramcrit10.MB
dM10 = M10[1:]-M10[:-1]

M30 = paramcrit30.MB
dM30 = M30[1:]-M30[:-1]

# %%
filename = 'PTm_profiles_v2.pdf'


f, (ax1, ax2, ax3) = plt.subplots(3, sharex=True, figsize = (3.5, 5.0))


ax1.loglog(r1, P1, color = 'blue', label = str(MB1)[:4] + r'$M_{\oplus}$')
ax1.loglog(r2, P2, color = 'green', linestyle = ':', linewidth = 2, label = str(MB2)[:4] + r'$M_{\oplus}$')
ax1.loglog(r3, P3, color = 'red', linestyle = '--', label = str(MB3)[:4] + r'$M_{\oplus}$')
ax1.semilogx(RB1, PB1, '.', ms = 10, color = 'blue')
ax1.semilogx(RB2, PB2, '.', ms = 10, color = 'green')
ax1.semilogx(RB3, PB3, '.', ms = 10, color = 'red')
ax1.semilogx(rcb1, Pcb1, '^', ms = 5, color = 'blue')
ax1.semilogx(rcb2, Pcb2, '^', ms = 5, color = 'green')
ax1.semilogx(rcb3, Pcb3, '^', ms = 5, color = 'red')
ax1.set_ylabel(r'P [dyne cm$^{-2}$]')
ax1.yaxis.set_ticks([10**(-2), 10, 10**4, 10**7, 10**10])
ax1.set_title(r'$a=60\mathrm{AU}$, $M_c=5 M_{\oplus}$')
ax1.legend(prop = {'size':10}, frameon = False, labelspacing = 0.2)
ax1.set_xlim(1.5, 4 * 10**4)
ax1.set_ylim(ymin = 2 * 10**(-5))

ax2.loglog(r1, T1, color = 'blue')
ax2.loglog(r2, T2, color = 'green', linestyle = ':', linewidth = 2)
ax2.loglog(r3, T3, color = 'red', linestyle = '--')
ax2.semilogx(RB1, TB1, '.', ms = 10, color = 'blue')
ax2.semilogx(RB2, TB2, '.', ms = 10, color = 'green')
ax2.semilogx(RB3, TB3, '.', ms = 10, color = 'red')
ax2.semilogx(rcb1, Tcb1, '^', ms = 5, color = 'blue')
ax2.semilogx(rcb2, Tcb2, '^', ms = 5, color = 'green')
ax2.semilogx(rcb3, Tcb3, '^', ms = 5, color = 'red')
ax2.set_ylim(10, 2 * 10**4)
ax2.set_ylabel(r'T [K]')
ax2.yaxis.set_ticks([10, 10**2, 10**3, 10**4])
#ax2.yaxis.set_ticks([10**(-2), 10, 10**4, 10**7, 10**10])
ax3.semilogx(r1, m1, color = 'blue')
ax3.semilogx(r2, m2, color = 'green', linestyle = ':', linewidth = 2)
ax3.semilogx(r3, m3, color = 'red', linestyle = '--')
ax3.semilogx(RB1, MB1, '.', ms = 10, color = 'blue', label = r'$R_{\mathrm{Bondi}}$')
ax3.semilogx(RB2, MB2, '.', ms = 10, color = 'green')
ax3.semilogx(RB3, MB3, '.', ms = 10, color = 'red')
ax3.semilogx(rcb1, Mcb1, '^', ms = 5, color = 'blue', label = r'$R_{\mathrm{RCB}}$')
ax3.semilogx(rcb2, Mcb2, '^', ms = 5, color = 'green')
ax3.semilogx(rcb3, Mcb3, '^', ms = 5, color = 'red')
#ax3.yaxis.set_ticks([4, 6, 8, 10])
ax3.set_ylim(4.2, 11.9)
ax3.set_ylabel(r'm [$M_{\oplus}$]')
ax3.set_xlabel(r'$r\,[R_{\oplus}]$')
ax3.legend(loc = 2, prop = {'size':13}, frameon = False, numpoints = 1, handletextpad = 0)

plt.tight_layout()
f.subplots_adjust(hspace=0)


plt.savefig(userpath + '/figs/ModelAtmospheres/RadSelfGravPoly/PaperFigs/' + filename)

# %%
L = paramcrit.L
t = 0 * numpy.ndarray(shape = (len(dtcrit)), dtype = float)

for i in range(len(t)):
    t[i] = sum(dtcrit[:i])

# %%
#for interactive reloading. OK to delete
import Analytical.analytic_comp as ac
reload(ac)
ansols = ac.analytic_sols

# %%
Pcb = numpy.logspace(-1, 2.775, 100)

an = ansols(Pcb, delad27, Y03, 3.2, a, Mc * Me)

Matman = an[1] / Me
Lan = an[2]
tcoolan = an[3]
rcb, Mrad, rHill = an[4], an[5] / Me, an[6]

# %%
filename2 = 'Lt_profiles.pdf'

f, ax2 = plt.subplots(2, sharex=True) #, figsize = (6.5, 3.5))

ax2[0].semilogy(M, L)
#ax2[0].semilogy(Mc + Matman, Lan, label = 'analytic')
ax2[0].set_ylabel(r'L [erg s$^{-1}$]')
ax2[0].set_title(r'$\nabla_{\mathrm{ad}}=2/7$, $\mu=2.35$, $a=10\mathrm{AU}$, $M_c=5 M_{\oplus}$')

#ax2[0].set_ylim(10**23, 10**26)

ax2[1].semilogy(M, t / (365 * 24 * 3600))
#ax2[1].semilogy(Mc + Matman, tcoolan)
ax2[1].set_ylabel(r't [years]')
ax2[1].set_xlabel(r'$M[M_{\oplus}]$')

plt.draw()
plt.tight_layout()

f.subplots_adjust(hspace=0)

plt.savefig(userpath + '/figs/ModelAtmospheres/RadSelfGravPoly/PaperFigs/' + filename2)

# %% [markdown]
# the following plot adds a (numerical) radiative zone mass on top of the analytic model for a fairer comparison

# %%
filename2 = 'Lt_profiles_v2.pdf'

f, ax2 = plt.subplots(2, sharex=True , figsize = (3.5, 4))

ax2[0].semilogy(M, L, label = 'numerical')
ax2[0].semilogy(Mc + Matman + Mrad, Lan, '--', label = 'analytic')
ax2[0].set_ylabel(r'L [erg s$^{-1}$]')
ax2[0].set_title(r'$a=60\mathrm{AU}$, $M_c=5 M_{\oplus}$')
ax2[0].legend(frameon = False)
ax2[0].set_ylim(3e23, 1e26)

ax2[1].semilogy(M, t / (365 * 24 * 3600))
ax2[1].semilogy(Mc + Matman + Mrad, tcoolan, '--')
ax2[1].set_ylabel(r't [years]')
ax2[1].set_xlabel(r'$M_{\rm{tot}}[M_{\oplus}]$')

#ax2[1].set_xlim(5,10)
ax2[1].set_ylim(1000, 2 * 10**8)
#ax2[0].set_ylim(5e22, 1e26)
ax2[0].set_xlim(5, 9)

plt.draw()
plt.tight_layout()

f.subplots_adjust(hspace=0) #this needs to be after a tight layoud
plt.savefig(userpath + '/figs/ModelAtmospheres/RadSelfGravPoly/PaperFigs/' + filename2)

# %% [markdown]
# The following just shows the difference between the analytic model without (original) and with (new) radiative zone mass

# %%
f, ax2 = plt.subplots(2, sharex=True, figsize = (6.5, 3.5))

#ax2[0].semilogy(M, L, label = 'numerical')
ax2[0].semilogy(Mc + Matman, Lan, label = 'analytic')
ax2[0].semilogy(Mc + Matman + Mrad, Lan, label = 'analytic+RZmass')
ax2[0].set_ylabel(r'L [erg s$^{-1}$]')
ax2[0].set_title(r'$\nabla_{\mathrm{ad}}=2/7$, $\mu=2.35$, $a=10\mathrm{AU}$, $M_c=5 M_{\oplus}$')
ax2[0].legend()
#ax2[0].set_ylim(10**23, 10**26)

#ax2[1].semilogy(M, t / (365 * 24 * 3600))
ax2[1].semilogy(Mc + Matman, tcoolan)
ax2[1].semilogy(Mc + Matman + Mrad, tcoolan)
ax2[1].set_ylabel(r't [years]')
ax2[1].set_xlabel(r'$M\;[M_{\oplus}]$')
ax2[1].set_xlim(5,10)
#plt.tight_layout()
# Out:
# (5, 10)

# %% [markdown]
# compare analytic vs. numeric at convective boundary (Just investigating OK to delete)

# %%
semilogy(paramcrit.Mcb, paramcrit.rcb) 
semilogy(Mc + Matman, rcb / Re)
set_xlabel('M_\mathrm{CB} [M_\oplus]'

# %%
filename2 = 'Mt_profile.pdf'

fig = plt.figure(figsize = (3.3, 3.3 * 0.75))
ax = fig.add_subplot(1,1,1)

#f, ax2 = plt.subplots(2, sharex=True) #, figsize = (6.5, 3.5))


ax.semilogy(M10[:-1] - Mc, (M10[:-1] - Mc)/dM10 * dtcrit10[:-1] / (365 * 24 * 3600), '--', label = r'%s AU' % str(int(a10)))
ax.semilogy(M30[:-1] - Mc, (M30[:-1] - Mc)/dM30 * dtcrit30[:-1] / (365 * 24 * 3600), ':', lw = 2, label = r'%s AU' % str(int(a30)))
ax.semilogy(M[:-1] - Mc, (M[:-1] - Mc)/dM * dtcrit[:-1] / (365 * 24 * 3600), label = r'%s AU' % str(int(a)))
ax.set_xticks((0, 1, 2, 3, 4))
ax.set_xticklabels(("0", "1", "2", "3", "4"))
#ax2[0].semilogy(Mc + Matman + Mrad, Lan, label = 'analytic')
ax.set_ylabel(r'$M_{\rm atm}/\dot{M}\, {\rm[years]}$')
ax.set_title(r'$M_c=5 M_{\oplus}$')
ax.set_xlabel(r'$M_{\rm{atm}}\, [M_{\oplus}]$')
ax.legend(loc = 8, frameon = False)
ax.set_ylim(10**4, 10**7)
ax.set_xlim(0, 4.2)
#ax2[0].legend()
#ax2[0].set_ylim(10**23, 10**26)

#ax2[1].semilogy(M, t / (365 * 24 * 3600))
#ax2[1].semilogy(Mc + Matman + Mrad, tcoolan)
#ax2[1].set_ylabel(r't [years]')
#ax2[1].set_xlabel(r'$M\;[M_{\oplus}]$')

#ax2[1].set_xlim(5,10)
#ax2[1].set_ylim(300,.9e9)
#ax2[0].set_ylim(5e22, 1e26)

#plt.draw()
plt.tight_layout()

#f.subplots_adjust(hspace=0) #this needs to be after a tight layoud
plt.savefig(userpath + '/figs/ModelAtmospheres/RadSelfGravPoly/PaperFigs/' + filename2)

# %%
f, ax2 = plt.subplots(2, sharex=True , figsize = (6.5, 3.5))

ax2[0].semilogy(M, L, label = 'numerical')
ax2[0].semilogy(Mc + Matman + Mrad, Lan, label = 'analytic')
ax2[0].set_ylabel(r'L [erg s$^{-1}$]')
ax2[0].set_title(r'$\nabla_{\mathrm{ad}}=2/7$, $\mu=2.35$, $a=10\mathrm{AU}$, $M_c=5 M_{\oplus}$')
ax2[0].legend()
#ax2[0].set_ylim(10**23, 10**26)

ax2[1].semilogy(M, t / (365 * 24 * 3600))
ax2[1].semilogy(Mc + Matman + Mrad, tcoolan)
ax2[1].set_ylabel(r't [years]')
ax2[1].set_xlabel(r'$M_{\rm{tot}}[M_{\oplus}]$')

ax2[1].set_xlim(5,10)
ax2[1].set_ylim(300,.9e9)
ax2[0].set_ylim(5e22, 1e26)

plt.draw()
plt.tight_layout()

f.subplots_adjust(hspace=0) #this needs to be after a tight layoud
#plt.savefig(userpath + '/figs/ModelAtmospheres/RadSelfGravPoly/' + filename2)

# %%
dM
# Out:
# array([ 0.0137441 ,  0.01433151,  0.01479365,  0.01515218,  0.01542739,
#         0.0156398 ,  0.01580755,  0.01594198,  0.01606504,  0.01616485,
#         0.01625111,  0.01632957,  0.01640243,  0.01647122,  0.01653702,
#         0.01660986,  0.01667646,  0.01673727,  0.01679717,  0.01685639,
#         0.01691509,  0.01697343,  0.0170403 ,  0.01710416,  0.01716203,
#         0.01721985,  0.01727763,  0.01733545,  0.01739332,  0.01745985,
#         0.01752502,  0.01758327,  0.01764164,  0.01770016,  0.01775883,
#         0.01781765,  0.01788519,  0.01795255,  0.01801201,  0.01807165,
#         0.01813151,  0.01819153,  0.01825175,  0.01832087,  0.01839067,
#         0.01845165,  0.01851283,  0.01857424,  0.01863586,  0.01869771,
#         0.01876879,  0.01884109,  0.01890374,  0.01896662,  0.01902973,
#         0.01909309,  0.01915667,  0.01923009,  0.01930482,  0.01936927,
#         0.01943396,  0.01949889,  0.01956408,  0.01962951,  0.01970568,
#         0.01978271,  0.01984904,  0.01991563,  0.01998248,  0.02004959,
#         0.02011695,  0.02019635,  0.0202755 ,  0.0203438 ,  0.02041238,
#         0.02048123,  0.02055035,  0.02061974,  0.02070294,  0.02078388,
#         0.02085426,  0.02092492,  0.02099586,  0.02106709,  0.02113858,
#         0.02122627,  0.02130863,  0.02138117,  0.021454  ,  0.02152712,
#         0.02160054,  0.02167425,  0.02176721,  0.0218505 ,  0.02192529,
#         0.0220004 ,  0.02207579,  0.02215149,  0.02222751,  0.02232672,
#         0.02241028,  0.02248743,  0.02256489,  0.02264267,  0.02272076,
#         0.02279918,  0.02290579,  0.02298882,  0.02306843,  0.02314836,
#         0.02322862,  0.02330921,  0.02339042,  0.02350518,  0.02358702,
#         0.02366918,  0.02375169,  0.02383455,  0.02391775,  0.02400694,
#         0.02412128,  0.02420578,  0.02429063,  0.02437583,  0.0244614 ,
#         0.02454733,  0.02464619,  0.02475883,  0.02484612,  0.02493377,
#         0.02502181,  0.0251102 ,  0.02519897,  0.02530949,  0.02541889,
#         0.02550909,  0.02559967,  0.02569065,  0.02578201,  0.02587377,
#         0.02599829,  0.02610255,  0.02619581,  0.02628946,  0.02638352,
#         0.02647798,  0.02657286,  0.02671414,  0.02681102,  0.02690746,
#         0.02700433,  0.02710161,  0.02719933,  0.02731002,  0.02744617,
#         0.02754552,  0.02764531,  0.02774554,  0.02784621,  0.02794733,
#         0.02807819,  0.02820458,  0.02830742,  0.02841071,  0.02851447,
#         0.02861868,  0.02872337,  0.0288785 ,  0.02899162,  0.02909811,
#         0.02920508,  0.02931253,  0.02942047,  0.02954302,  0.02969896,
#         0.02980879,  0.02991912,  0.03002995,  0.03014128,  0.03025312,
#         0.03040588,  0.03054388,  0.03065771,  0.03077206,  0.03088694,
#         0.03100234,  0.03112112,  0.03130455,  0.03142204,  0.03154008,
#         0.03165866,  0.03177779,  0.03189746,  0.03205462,  0.03221338,
#         0.03233526,  0.03245772,  0.03258074,  0.03270433,  0.03282852,
#         0.03303193,  0.03315898,  0.03328548,  0.03341257,  0.03354026,
#         0.03366855])

# %%
M10 - Mc
# Out:
# array([ 0.18438637,  0.19813047,  0.21246198,  0.22725563,  0.24240781,
#         0.25783521,  0.27347501,  0.28928256,  0.30522453,  0.32128958,
#         0.33745443,  0.35370555,  0.37003512,  0.38643755,  0.40290877,
#         0.41944579,  0.43605565,  0.45273212,  0.46946939,  0.48626656,
#         0.50312295,  0.52003804,  0.53701147,  0.55405177,  0.57115592,
#         0.58831795,  0.6055378 ,  0.62281543,  0.64015088,  0.6575442 ,
#         0.67500405,  0.69252907,  0.71011234,  0.72775399,  0.74545415,
#         0.76321298,  0.78103063,  0.79891582,  0.81686838,  0.83488039,
#         0.85295204,  0.87108355,  0.88927508,  0.90752683,  0.9258477 ,
#         0.94423838,  0.96269002,  0.98120286,  0.9997771 ,  1.01841296,
#         1.03711067,  1.05587946,  1.07472055,  1.09362429,  1.11259091,
#         1.13162064,  1.15071373,  1.1698704 ,  1.1891005 ,  1.20840532,
#         1.22777459,  1.24720854,  1.26670743,  1.28627152,  1.30590102,
#         1.3256067 ,  1.34538941,  1.36523845,  1.38515408,  1.40513656,
#         1.42518615,  1.4453031 ,  1.46549945,  1.48577495,  1.50611875,
#         1.52653113,  1.54701236,  1.56756271,  1.58818244,  1.60888538,
#         1.62966926,  1.65052353,  1.67144845,  1.69244431,  1.71351141,
#         1.73464999,  1.75587626,  1.77718489,  1.79856606,  1.82002006,
#         1.84154719,  1.86314772,  1.88482197,  1.90658918,  1.92843968,
#         1.95036498,  1.97236538,  1.99444117,  2.01659266,  2.03882017,
#         2.06114689,  2.08355717,  2.1060446 ,  2.12860949,  2.15125216,
#         2.17397292,  2.1967721 ,  2.21967789,  2.24266672,  2.26573514,
#         2.2888835 ,  2.31211212,  2.33542133,  2.35881175,  2.38231693,
#         2.40590395,  2.42957313,  2.45332482,  2.47715937,  2.50107711,
#         2.52508405,  2.54920533,  2.5734111 ,  2.59770173,  2.62207756,
#         2.64653896,  2.67108629,  2.69573248,  2.72049131,  2.74533742,
#         2.7702712 ,  2.795293  ,  2.8204032 ,  2.84560217,  2.87091167,
#         2.89633055,  2.92183964,  2.94743931,  2.97312996,  2.99891197,
#         3.02478574,  3.05078403,  3.07688658,  3.10308239,  3.12937185,
#         3.15575536,  3.18223335,  3.20880621,  3.23552035,  3.26233136,
#         3.28923883,  3.31624315,  3.34334477,  3.37054409,  3.39785411,
#         3.42530028,  3.45284581,  3.48049112,  3.50823667,  3.53608288,
#         3.56403021,  3.59210841,  3.62031298,  3.6486204 ,  3.67703111,
#         3.70554558,  3.73416426,  3.76288763,  3.79176613,  3.82075774,
#         3.84985585,  3.87906094,  3.90837347,  3.93779394,  3.96733696,
#         3.99703592,  4.02684471,  4.05676383,  4.08679379,  4.11693507,
#         4.14718818,  4.17759407,  4.20813795,  4.23879566,  4.26956772,
#         4.30045466,  4.331457  ,  4.36257812,  4.39388267,  4.42530471,
#         4.45684479,  4.48850345,  4.52028123,  4.5521787 ,  4.58423332,
#         4.6164467 ,  4.64878196,  4.68123968,  4.71382042,  4.74652475,
#         4.77935327,  4.8123852 ,  4.84554418,  4.87882966,  4.91224223,
#         4.94578249,  4.97945104])
